# %% [markdown]
# # Applied Data Science Capstone
#
# This notebook will be used to answer deliverables for the Data Science Capstone

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import geocoder
import os
import json # library to handle JSON files
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
# import k-means from clustering stage
from sklearn.cluster import KMeans
import folium # map rendering library

# %% [markdown]
# ## Week 3 Capstone Deliverable
#
# ### Extracting dataset and build dataframe
# After retreiving the URL and creating a Beautiful soup object**
#
# Firstly create a list
#
# Later after finding the table and table data  create a dictionary called cell having 3 keys PostalCode, Borough and Neighborhood.
#
# As postal code contains upto 3 characters extract that using tablerow.p.text
#
# Next use split ,strip and replace functions for getting Borough and Neighborhood information.
# Append to the list
#
# Create a dataframe with list

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
html_data = requests.get(url).text
soup = BeautifulSoup(html_data, 'html5lib')

table_contents=[]
table=soup.find('table')
for row in table.findAll('td'):
    cell = {}
    if row.span.text=='Not assigned':
        pass
    else:
        cell['PostalCode'] = row.p.text[:3]
        cell['Borough'] = (row.span.text).split('(')[0]
        cell['Neighborhood'] = (((((row.span.text).split('(')[1]).strip(')')).replace(' /',',')).replace(')',' ')).strip(' ')
        table_contents.append(cell)

# print(table_contents)
df=pd.DataFrame(table_contents)
df['Borough']=df['Borough'].replace({'Downtown TorontoStn A PO Boxes25 The Esplanade':'Downtown Toronto Stn A',
                                             'East TorontoBusiness reply mail Processing Centre969 Eastern':'East Toronto Business',
                                             'EtobicokeNorthwest':'Etobicoke Northwest','East YorkEast Toronto':'East York/East Toronto',
                                             'MississaugaCanada Post Gateway Processing Centre':'Mississauga'})


df.shape
# Out:
# (103, 3)

# %% [markdown]
# ### Append latitude / longitude to dataset

# %%
def getLatLong(postal_code):
    # initialize your variable to None
    lat_lng_coords = None
    # loop until you get the coordinates
    while(lat_lng_coords is None):
        g = geocoder.bing('{}, Toronto, Ontario'.format(postal_code),key=os.environ.get('BING_API_KEY'))
        lat_lng_coords = g.latlng
    latitude = lat_lng_coords[0]
    longitude = lat_lng_coords[1]
    return [latitude,longitude]

for index, row in df.iterrows():
    latlng = getLatLong(row['PostalCode'])
    df.loc[index,'latitude'] = latlng[0]
    df.loc[index,'longitude'] = latlng[1]
    
df.head()
# Out:
#   PostalCode           Borough                      Neighborhood   latitude  \
# 0        M3A        North York                         Parkwoods  43.756123
# 1        M4A        North York                  Victoria Village  43.726780
# 2        M5A  Downtown Toronto         Regent Park, Harbourfront  43.654842
# 3        M6A        North York  Lawrence Manor, Lawrence Heights  43.721996
# 4        M7A      Queen's Park     Ontario Provincial Government  43.663910
#
#    longitude
# 0 -79.329636
# 1 -79.310738
# 2 -79.365379
# 3 -79.445915
# 4 -79.388733

# %% [markdown]
# ### Display Map with Neighborhoods Plotted as Markers

# %%
lat_lng_coords = None
# loop until you get the coordinates
while(lat_lng_coords is None):
    g = geocoder.bing('{}, Toronto, Ontario',key=os.environ.get('BING_API_KEY'))
    lat_lng_coords = g.latlng
    
map_toronto = folium.Map(location=[lat_lng_coords[0], lat_lng_coords[1]], zoom_start=11)

# add markers to map
for index, row in df.iterrows():
    lat = row['latitude']
    lng = row['longitude']
    label = row['Neighborhood']
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_8941b896123b41e3b165062da11b3022%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_8941b896123b41e3b165062da11b3022%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_8941b896123b41e3b165062da11b3022%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_8941b896123b41e3b165062da11b3022%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B43.651893615722656%2C-79.3817138671875%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20 ...

# %% [markdown]
# ### Poll Foursquare Data on Neighborhoods

# %%
CLIENT_ID = key=os.environ.get('FOURSQUARE_CLIENT')
CLIENT_SECRET = key=os.environ.get('FOURSQUARE_SECRET')
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        #print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

toronto_venues = getNearbyVenues(names=df['Neighborhood'],
                                   latitudes=df['latitude'],
                                   longitudes=df['longitude']
                                  )

print(toronto_venues.shape)
toronto_venues.head()
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))

# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

#toronto_onehot.head()
# Out:
# (2581, 7)
# There are 267 uniques categories.

# %% [markdown]
# ### Process Data for K-means Clustering

# %%
toronto_onehot.shape
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped
toronto_grouped.shape
num_top_venues = 5

for hood in toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
    
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 20

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
# ----Agincourt----
#                 venue  freq
# 0  Chinese Restaurant   0.2
# 1                Pool   0.1
# 2        Intersection   0.1
# 3                Bank   0.1
# 4       Shopping Mall   0.1
#
#
# ----Alderwood, Long Branch----
#                              venue  freq
# 0                   Breakfast Spot   1.0
# 1                      Opera House   0.0
# 2               Miscellaneous Shop   0.0
# 3       Modern European Restaurant   0.0
# 4  Molecular Gastronomy Restaurant   0.0
#
#
# ----Bathurst Manor, Wilson Heights, Downsview North----
#                        venue  freq
# 0  Middle Eastern Restaurant  0.25
# 1   Mediterranean Restaurant  0.25
# 2                Pizza Place  0.25
# 3                       Park  0.25
# 4                     Museum  0.00
#
#
# ----Bayview Village----
#           venue  freq
# 0       Dog Run   0.5
# 1  Tennis Court   0.5
# 2  Music School   0.0
# 3  Noodle House   0.0
# 4     Nightclub   0.0
#
#
# ----Bedford Park, Lawrence Manor East----
#                 venue  freq
# 0         Coffee Shop  0.12
# 1  Italian Restaurant  0.12
# 2      Sandwich Place  0.08
# 3       Women's Store  0.04
# 4              Bakery  0.04
#
#
# ----Berczy Park----
#                  venue  freq
# 0          Coffee Shop  0.09
# 1   Italian Restaurant  0.05
# 2  Japanese Restaurant  0.04
# 3   Seafood Restaurant  0.04
# 4                 Café  0.04
#
#
# ----Birch Cliff, Cliffside West----
#                    venue  freq
# 0  General Entertainment  0.25
# 1           Skating Rink  0.25
# 2        College Stadium  0.25
# 3                   Café  0.25
# 4            Yoga Studio  0.00
#
#
# ----Brockton, Parkdale Village, Exhibition Place----
#          venue  freq
# 0          Bar  0.08
# 1   Restaurant  0.06
# 2         Café  0.06
# 3    Gift Shop  0.05
# 4  Coffee Shop  0.05
#
#
# ----CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport----
#                 venue  freq
# 0         Coffee Shop  0.10
# 1  Italian Restaurant  0.07
# 2               Hotel  0.05
# 3                Café  0.05
# 4            Beer Bar  0.03
#
#
# ----Caledonia-Fairbanks----
#                  venue  freq
# 0   Mexican Restaurant  0.14
# 1  Sporting Goods Shop  0.14
# 2               Bakery  0.14
# 3                  Gym  0.14
# 4           Beer Store  0.14
#
#
# ----Cedarbrae----
#                      venue  freq
# 0              Gaming Cafe   0.5
# 1                    Trail   0.5
# 2              Yoga Studio   0.0
# 3                Nightclub   0.0
# 4  New American Restaurant   0.0
#
#
# ----Central Bay Street----
#                 venue  freq
# 0         Coffee Shop  0.18
# 1  Italian Restaurant  0.05
# 2     Bubble Tea Shop  0.03
# 3                Café  0.03
# 4    Sushi Restaurant  0.03
#
#
# ----Christie----
#                venue  freq
# 0  Korean Restaurant  0.19
# 1      Grocery Store  0.14
# 2               Café  0.14
# 3        Coffee Shop  0.10
# 4     Sandwich Place  0.05
#
#
# ----Church and Wellesley----
#                  venue  freq
# 0          Coffee Shop  0.08
# 1  Japanese Restaurant  0.06
# 2     Sushi Restaurant  0.06
# 3           Restaurant  0.05
# 4                 Café  0.04
#
#
# ----Clairville, Humberwood, Woodbine Downs, West Humber, Kipling Heights, Rexdale, Elms, Tandridge, Old Rexdale----
#              venue  freq
# 0   Shop & Service  0.33
# 1  Automotive Shop  0.33
# 2      Coffee Shop  0.33
# 3      Yoga Studio  0.00
# 4      Opera House  0.00
#
#
# ----Clarks Corners, Tam O'Shanter, Sullivan----
#                 venue  freq
# 0         Pizza Place  0.17
# 1   Convenience Store  0.08
# 2  Chinese Restaurant  0.08
# 3                Bank  0.08
# 4       Shopping Mall  0.08
#
#
# ----Cliffside, Cliffcrest, Scarborough Village West----
#             venue  freq
# 0          Bistro   0.2
# 1        Pharmacy   0.2
# 2  Sandwich Place   0.2
# 3     Coffee Shop   0.2
# 4       Gift Shop   0.2
#
#
# ----Commerce Court, Victoria Hotel----
#                  venue  freq
# 0          Coffee Shop  0.12
# 1                Hotel  0.06
# 2                 Café  0.05
# 3           Restaurant  0.05
# 4  Japanese Restaurant  0.04
#
#
# ----Davisville----
#                 venue  freq
# 0         Pizza Place  0.10
# 1        Dessert Shop  0.10
# 2                Café  0.07
# 3  Italian Restaurant  0.07
# 4      Sandwich Place  0.07
#
#
# ----Davisville North----
#                   venue  freq
# 0           Coffee Shop  0.09
# 1    Italian Restaurant  0.06
# 2           Pizza Place  0.06
# 3  Fast Food Restaurant  0.06
# 4                   Pub  0.04
#
#
# ----Del Ray, Mount Dennis, Keelsdale and Silverthorn----
#                   venue  freq
# 0          Intersection   0.4
# 1  Fast Food Restaurant   0.4
# 2            Playground   0.2
# 3                Museum   0.0
# 4             Nightclub   0.0
#
#
# ----Don Mills South----
#             venue  freq
# 0     Coffee Shop  0.11
# 1             Gym  0.11
# 2      Restaurant  0.11
# 3   Grocery Store  0.05
# 4  Discount Store  0.05
#
#
# ----Dorset Park, Wexford Heights, Scarborough Town Centre----
#                              venue  freq
# 0                          Brewery  0.33
# 1                           Bakery  0.33
# 2                 Asian Restaurant  0.33
# 3       Modern European Restaurant  0.00
# 4  Molecular Gastronomy Restaurant  0.00
#
#
# ----Downsview Central----
#             venue  freq
# 0  Baseball Field   0.5
# 1    Home Service   0.5
# 2          Museum   0.0
# 3    Noodle House   0.0
# 4       Nightclub   0.0
#
#
# ----Downsview East----
#                        venue  freq
# 0         Turkish Restaurant  0.33
# 1                      Hotel  0.17
# 2  Latin American Restaurant  0.17
# 3      Vietnamese Restaurant  0.17
# 4         Italian Restaurant  0.17
#
#
# ----Downsview Northwest----
#                   venue  freq
# 0         Grocery Store   0.1
# 1           Pizza Place   0.1
# 2         Shopping Mall   0.1
# 3  Fast Food Restaurant   0.1
# 4        Discount Store   0.1
#
#
# ----Downsview West----
#            venue  freq
# 0  Grocery Store   1.0
# 1    Yoga Studio   0.0
# 2   Music School   0.0
# 3   Noodle House   0.0
# 4      Nightclub   0.0
#
#
# ----Dufferin, Dovercourt Village----
#                 venue  freq
# 0                Park  0.11
# 1       Grocery Store  0.11
# 2  Athletics & Sports  0.05
# 3            Pharmacy  0.05
# 4                 Bar  0.05
#
#
# ----Enclave of L4W----
#             venue  freq
# 0           Hotel  0.07
# 1     Coffee Shop  0.07
# 2            Café  0.06
# 3  Clothing Store  0.04
# 4      Restaurant  0.04
#
#
# ----Enclave of M4L----
#             venue  freq
# 0           Hotel  0.07
# 1     Coffee Shop  0.07
# 2            Café  0.06
# 3  Clothing Store  0.04
# 4      Restaurant  0.04
#
#
# ----Enclave of M5E----
#           venue  freq
# 0   Coffee Shop  0.15
# 1         Hotel  0.06
# 2    Restaurant  0.06
# 3  Cocktail Bar  0.04
# 4      Beer Bar  0.04
#
#
# ----Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood----
#           venue  freq
# 0      Pharmacy  0.14
# 1   Coffee Shop  0.14
# 2  Liquor Store  0.14
# 3    Beer Store  0.14
# 4          Café  0.14
#
#
# ----Fairview, Henry Farm, Oriole----
#                   venue  freq
# 0        Clothing Store  0.13
# 1  Fast Food Restaurant  0.06
# 2           Coffee Shop  0.06
# 3         Women's Store  0.04
# 4                  Bank  0.04
#
#
# ----First Canadian Place, Underground city----
#                  venue  freq
# 0          Coffee Shop  0.10
# 1                 Café  0.07
# 2                Hotel  0.07
# 3                  Gym  0.04
# 4  Japanese Restaurant  0.04
#
#
# ----Forest Hill North & West----
#                      venue  freq
# 0                 Pharmacy   1.0
# 1            Movie Theater   0.0
# 2                Nightclub   0.0
# 3  New American Restaurant   0.0
# 4              Music Venue   0.0
#
#
# ----Garden District, Ryerson----
#             venue  freq
# 0     Coffee Shop  0.11
# 1  Clothing Store  0.06
# 2  Sandwich Place  0.04
# 3            Café  0.04
# 4           Hotel  0.04
#
#
# ----Glencairn----
#                        venue  freq
# 0              Grocery Store  0.18
# 1  Latin American Restaurant  0.09
# 2                Gas Station  0.09
# 3                       Bank  0.09
# 4   Mediterranean Restaurant  0.09
#
#
# ----Golden Mile, Clairlea, Oakridge----
#            venue  freq
# 0         Bakery  0.29
# 1  Metro Station  0.14
# 2       Bus Line  0.14
# 3    Bus Station  0.14
# 4   Intersection  0.14
#
#
# ----Guildwood, Morningside, West Hill----
#                   venue  freq
# 0           Pizza Place  0.17
# 1  Fast Food Restaurant  0.09
# 2                  Bank  0.09
# 3     Electronics Store  0.04
# 4           Supermarket  0.04
#
#
# ----Harbourfront East, Union Station, Toronto Islands----
#            venue  freq
# 0  Boat or Ferry  0.09
# 1    Coffee Shop  0.09
# 2          Plaza  0.04
# 3          Hotel  0.04
# 4     Restaurant  0.04
#
#
# ----High Park, The Junction South----
#                 venue  freq
# 0                Café  0.11
# 1  Mexican Restaurant  0.11
# 2           Gastropub  0.05
# 3           Bookstore  0.05
# 4       Grocery Store  0.05
#
#
# ----Hillcrest Village----
#                                       venue  freq
# 0                                      Park   0.5
# 1  Residential Building (Apartment / Condo)   0.5
# 2                               Yoga Studio   0.0
# 3                                    Museum   0.0
# 4                                 Nightclub   0.0
#
#
# ----Humber Summit----
#                      venue  freq
# 0   Furniture / Home Store   0.5
# 1         Business Service   0.5
# 2                Nightclub   0.0
# 3  New American Restaurant   0.0
# 4              Music Venue   0.0
#
#
# ----Humberlea, Emery----
#                        venue  freq
# 0                Coffee Shop  0.29
# 1  Latin American Restaurant  0.14
# 2           Business Service  0.14
# 3             Discount Store  0.14
# 4                  Nightclub  0.14
#
#
# ----Humewood-Cedarvale----
#             venue  freq
# 0         Dog Run  0.14
# 1            Park  0.14
# 2    Tennis Court  0.14
# 3    Hockey Arena  0.14
# 4  Soccer Stadium  0.14
#
#
# ----India Bazaar, The Beaches West----
#                   venue  freq
# 0         Grocery Store  0.08
# 1             Pet Store  0.06
# 2    Italian Restaurant  0.06
# 3                   Gym  0.06
# 4  Fast Food Restaurant  0.06
#
#
# ----Islington Avenue----
#            venue  freq
# 0       Pharmacy  0.25
# 1           Bank  0.12
# 2  Shopping Mall  0.12
# 3   Skating Rink  0.12
# 4  Grocery Store  0.12
#
#
# ----Kennedy Park, Ionview, East Birchmount Park----
#                venue  freq
# 0        Coffee Shop  0.25
# 1   Department Store  0.12
# 2  Convenience Store  0.12
# 3      Metro Station  0.12
# 4         Hobby Shop  0.12
#
#
# ----Kensington Market, Chinatown, Grange Park----
#                   venue  freq
# 0                  Café  0.06
# 1                Bakery  0.04
# 2        Clothing Store  0.04
# 3                  Park  0.04
# 4  Caribbean Restaurant  0.04
#
#
# ----Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens----
#                  venue  freq
# 0             Bus Line  0.25
# 1        Jewelry Store  0.25
# 2          Pizza Place  0.25
# 3  Arts & Crafts Store  0.25
# 4          Yoga Studio  0.00
#
#
# ----Lawrence Manor, Lawrence Heights----
#                venue  freq
# 0        Coffee Shop  0.25
# 1  Convenience Store  0.12
# 2      Metro Station  0.12
# 3             Bakery  0.12
# 4           Platform  0.12
#
#
# ----Lawrence Park----
#          venue  freq
# 0  Yoga Studio  0.11
# 1         Park  0.11
# 2         Pool  0.11
# 3     Bus Line  0.11
# 4         Bank  0.11
#
#
# ----Leaside----
#                  venue  freq
# 0  Sporting Goods Shop  0.22
# 1                 Bank  0.22
# 2           Restaurant  0.11
# 3           Sports Bar  0.11
# 4     Sushi Restaurant  0.11
#
#
# ----Little Portugal, Trinity----
#                            venue  freq
# 0                            Bar  0.10
# 1          Vietnamese Restaurant  0.05
# 2               Asian Restaurant  0.05
# 3  Vegetarian / Vegan Restaurant  0.05
# 4                    Yoga Studio  0.02
#
#
# ----Malvern, Rouge----
#                   venue  freq
# 0            Hobby Shop  0.33
# 1         Design Studio  0.33
# 2  Fast Food Restaurant  0.33
# 3           Yoga Studio  0.00
# 4          Music School  0.00
#
#
# ----Milliken, Agincourt North, Steeles East, L'Amoreaux East----
#                      venue  freq
# 0                 Pharmacy  0.67
# 1             Intersection  0.33
# 2                Nightclub  0.00
# 3  New American Restaurant  0.00
# 4              Music Venue  0.00
#
#
# ----Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West----
#              venue  freq
# 0    Grocery Store  0.07
# 1             Bank  0.07
# 2  Supplement Shop  0.07
# 3   Hardware Store  0.07
# 4    Tanning Salon  0.07
#
#
# ----Moore Park, Summerhill East----
#                 venue  freq
# 0  Italian Restaurant  0.12
# 1         Coffee Shop  0.08
# 2       Grocery Store  0.08
# 3                Park  0.05
# 4                Café  0.05
#
#
# ----New Toronto, Mimico South, Humber Bay Shores----
#                   venue  freq
# 0           Coffee Shop   0.2
# 1          Liquor Store   0.2
# 2  Fast Food Restaurant   0.2
# 3           Pizza Place   0.2
# 4                  Café   0.2
#
#
# ----North Park, Maple Leaf Park, Upwood Park----
#               venue  freq
# 0  Basketball Court  0.33
# 1            Bakery  0.33
# 2      Home Service  0.33
# 3       Music Store  0.00
# 4            Office  0.00
#
#
# ----North Toronto West----
#                 venue  freq
# 0  Italian Restaurant  0.09
# 1                Café  0.06
# 2         Coffee Shop  0.06
# 3               Diner  0.06
# 4     Thai Restaurant  0.04
#
#
# ----Northwood Park, York University----
#                     venue  freq
# 0  Furniture / Home Store  0.20
# 1             Pizza Place  0.13
# 2             Coffee Shop  0.07
# 3      Miscellaneous Shop  0.07
# 4    Caribbean Restaurant  0.07
#
#
# ----Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East----
#             venue  freq
# 0            Park  0.67
# 1  Baseball Field  0.33
# 2    Music School  0.00
# 3    Noodle House  0.00
# 4       Nightclub  0.00
#
#
# ----Ontario Provincial Government----
#                  venue  freq
# 0     Sushi Restaurant  0.07
# 1   Italian Restaurant  0.07
# 2          Coffee Shop  0.07
# 3  Distribution Center  0.04
# 4      Bubble Tea Shop  0.04
#
#
# ----Parkdale, Roncesvalles----
#                          venue  freq
# 0                  Coffee Shop  0.08
# 1                       Bakery  0.07
# 2             Sushi Restaurant  0.05
# 3  Eastern European Restaurant  0.05
# 4              Thai Restaurant  0.05
#
#
# ----Parkview Hill, Woodbine Gardens----
#                   venue  freq
# 0                   Pub  0.17
# 1                  Road  0.17
# 2                  Café  0.17
# 3  Gym / Fitness Center  0.17
# 4           Coffee Shop  0.17
#
#
# ----Parkwoods----
#                  venue  freq
# 0             Bus Stop   0.4
# 1    Convenience Store   0.2
# 2  Fried Chicken Joint   0.2
# 3         Intersection   0.2
# 4         Music School   0.0
#
#
# ----Regent Park, Harbourfront----
#                 venue  freq
# 0         Coffee Shop  0.19
# 1  Italian Restaurant  0.11
# 2             Theater  0.07
# 3      Breakfast Spot  0.07
# 4              Bakery  0.04
#
#
# ----Richmond, Adelaide, King----
#          venue  freq
# 0         Café  0.07
# 1  Coffee Shop  0.06
# 2        Hotel  0.06
# 3          Gym  0.04
# 4   Restaurant  0.04
#
#
# ----Rosedale----
#             venue  freq
# 0     Coffee Shop   0.2
# 1            Park   0.2
# 2            Bank   0.1
# 3  Sandwich Place   0.1
# 4        Pie Shop   0.1
#
#
# ----Roselawn----
#           venue  freq
# 0  Home Service   0.5
# 1  Liquor Store   0.5
# 2   Yoga Studio   0.0
# 3        Museum   0.0
# 4     Nightclub   0.0
#
#
# ----Rouge Hill, Port Union, Highland Creek----
#                      venue  freq
# 0                     Park   1.0
# 1              Yoga Studio   0.0
# 2                   Museum   0.0
# 3                Nightclub   0.0
# 4  New American Restaurant   0.0
#
#
# ----Runnymede, Swansea----
#                 venue  freq
# 0                Café  0.14
# 1                Bank  0.05
# 2         Pizza Place  0.05
# 3  Italian Restaurant  0.05
# 4              Bakery  0.05
#
#
# ----Runnymede, The Junction North----
#                 venue  freq
# 0             Brewery  0.75
# 1  Athletics & Sports  0.25
# 2        Music School  0.00
# 3        Noodle House  0.00
# 4           Nightclub  0.00
#
#
# ----Scarborough Village----
#                        venue  freq
# 0  Middle Eastern Restaurant  0.33
# 1                 Playground  0.33
# 2              Grocery Store  0.33
# 3                     Museum  0.00
# 4                  Nightclub  0.00
#
#
# ----South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens----
#                   venue  freq
# 0         Grocery Store  0.15
# 1           Auto Garage  0.08
# 2              Pharmacy  0.08
# 3          Liquor Store  0.08
# 4  Caribbean Restaurant  0.08
#
#
# ----St. James Town----
#                 venue  freq
# 0         Coffee Shop  0.07
# 1  Seafood Restaurant  0.04
# 2                Café  0.04
# 3              Bakery  0.03
# 4           Gastropub  0.03
#
#
# ----St. James Town, Cabbagetown----
#                 venue  freq
# 0         Coffee Shop  0.12
# 1              Bakery  0.06
# 2         Pizza Place  0.06
# 3                 Pub  0.04
# 4  Italian Restaurant  0.04
#
#
# ----Steeles West, L'Amoreaux West----
#                   venue  freq
# 0  Fast Food Restaurant  0.17
# 1    Chinese Restaurant  0.08
# 2                  Bank  0.08
# 3          Camera Store  0.08
# 4           Pizza Place  0.08
#
#
# ----Studio District----
#                  venue  freq
# 0          Coffee Shop  0.07
# 1            Gastropub  0.05
# 2  American Restaurant  0.05
# 3                 Park  0.05
# 4                 Café  0.05
#
#
# ----Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park----
#                 venue  freq
# 0         Coffee Shop   0.4
# 1  Light Rail Station   0.2
# 2        Liquor Store   0.2
# 3         Supermarket   0.2
# 4        Music School   0.0
#
#
# ----The Annex, North Midtown, Yorkville----
#                 venue  freq
# 0  Italian Restaurant  0.14
# 1                Café  0.09
# 2      Sandwich Place  0.09
# 3                 Pub  0.05
# 4         Coffee Shop  0.05
#
#
# ----The Beaches----
#                venue  freq
# 0                Pub  0.25
# 1  Health Food Store  0.25
# 2              Trail  0.25
# 3        Yoga Studio  0.00
# 4             Museum  0.00
#
#
# ----The Danforth  East----
#                venue  freq
# 0  Convenience Store   0.5
# 1               Park   0.5
# 2        Yoga Studio   0.0
# 3             Museum   0.0
# 4          Nightclub   0.0
#
#
# ----The Danforth West, Riverdale----
#                 venue  freq
# 0    Greek Restaurant  0.16
# 1         Coffee Shop  0.09
# 2  Italian Restaurant  0.07
# 3      Ice Cream Shop  0.04
# 4       Grocery Store  0.04
#
#
# ----The Kingsway, Montgomery Road, Old Mill North----
#                         venue  freq
# 0                        Pool   0.5
# 1                      Lounge   0.5
# 2                      Office   0.0
# 3          Miscellaneous Shop   0.0
# 4  Modern European Restaurant   0.0
#
#
# ----Thorncliffe Park----
#                venue  freq
# 0  Indian Restaurant  0.09
# 1     Sandwich Place  0.09
# 2        Yoga Studio  0.05
# 3     Discount Store  0.05
# 4       Burger Joint  0.05
#
#
# ----Toronto Dominion Centre, Design Exchange----
#          venue  freq
# 0  Coffee Shop  0.10
# 1        Hotel  0.08
# 2         Café  0.06
# 3   Restaurant  0.04
# 4       Bakery  0.03
#
#
# ----University of Toronto, Harbord----
#          venue  freq
# 0         Café  0.14
# 1  Coffee Shop  0.08
# 2   Restaurant  0.05
# 3    Bookstore  0.05
# 4         Park  0.05
#
#
# ----Upper Rouge----
#           venue  freq
# 0  Home Service   0.5
# 1          Park   0.5
# 2   Yoga Studio   0.0
# 3        Museum   0.0
# 4     Nightclub   0.0
#
#
# ----Victoria Village----
#                         venue  freq
# 0                        Park  0.29
# 1       Portuguese Restaurant  0.14
# 2  Financial or Legal Service  0.14
# 3                 Pizza Place  0.14
# 4                Intersection  0.14
#
#
# ----West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale----
#                        venue  freq
# 0         Chinese Restaurant  0.25
# 1  Middle Eastern Restaurant  0.25
# 2                     Bakery  0.25
# 3                Pizza Place  0.25
# 4                Music Store  0.00
#
#
# ----Westmount----
#                        venue  freq
# 0  Middle Eastern Restaurant   0.1
# 1             Ice Cream Shop   0.1
# 2                Flea Market   0.1
# 3                 Playground   0.1
# 4         Chinese Restaurant   0.1
#
#
# ----Weston----
#                  venue  freq
# 0                Diner  0.25
# 1        Grocery Store  0.25
# 2  Fried Chicken Joint  0.25
# 3             Pharmacy  0.25
# 4          Yoga Studio  0.00
#
#
# ----Wexford, Maryvale----
#                         venue  freq
# 0                  Food Court   0.5
# 1           Electronics Store   0.5
# 2                      Office   0.0
# 3          Miscellaneous Shop   0.0
# 4  Modern European Restaurant   0.0
#
#
# ----Willowdale South----
#                   venue  freq
# 0      Ramen Restaurant  0.07
# 1   Japanese Restaurant  0.07
# 2           Coffee Shop  0.07
# 3           Pizza Place  0.05
# 4  Fast Food Restaurant  0.05
#
#
# ----Willowdale West----
#                venue  freq
# 0  Convenience Store  0.17
# 1        Coffee Shop  0.17
# 2             Bakery  0.17
# 3           Bus Line  0.17
# 4               Park  0.17
#
#
# ----Willowdale, Newtonbrook----
#               venue  freq
# 0    Sandwich Place   0.2
# 1       Pizza Place   0.2
# 2              Park   0.2
# 3  Sushi Restaurant   0.2
# 4       Coffee Shop   0.2
#
#
# ----Woburn----
#               venue  freq
# 0       Coffee Shop  0.50
# 1              Park  0.25
# 2  Business Service  0.25
# 3       Yoga Studio  0.00
# 4      Noodle House  0.00
#
#
# ----Woodbine Heights----
#             venue  freq
# 0             Pub  0.08
# 1     Gas Station  0.08
# 2      Playground  0.08
# 3             Bar  0.08
# 4  Breakfast Spot  0.08
#
#
# ----York Mills West----
#                venue  freq
# 0  Convenience Store  0.33
# 1          Speakeasy  0.33
# 2               Park  0.33
# 3        Yoga Studio  0.00
# 4       Music School  0.00
#
#
# ----York Mills, Silver Hills----
#           venue  freq
# 0          Pool   0.5
# 1  Concert Hall   0.5
# 2        Museum   0.0
# 3  Noodle House   0.0
# 4     Nightclub   0.0
#                                       Neighborhood      1st Most Common Venue  \
# 0                                        Agincourt         Chinese Restaurant
# 1                           Alderwood, Long Branch             Breakfast Spot
# 2  Bathurst Manor, Wilson Heights, Downsview North  Middle Eastern Restaurant
# 3                                  Bayview Village                    Dog Run
# 4                Bedford Park, Lawrence Manor East                Coffee Shop
#
#       2nd Most Common Venue 3rd Most Common Venue       4th Most Common Venue  \
# 0                      Pool          Intersection                        Bank
# 1               Opera House    Miscellaneous Shop  Modern European Restaurant
# 2  Mediterranean Restaurant           Pizza Place                        Park
# 3              Tennis Court          Music School                Noodle House
# 4        Italian Restaurant        Sandwich Place               Women's Store
#
#              5th Most Common Venue    6th Most Common Venue  \
# 0                    Shopping Mall             Skating Rink
# 1  Molecular Gastronomy Restaurant      Monument / Landmark
# 2                           Museum  New American Restaurant
# 3                        Nightclub  New American Restaurant
# 4                           Bakery              Pizza Place
#
#   7th Most Common Venue    8th Most Common Venue 9th Most Common Venue  ...  \
# 0      Asian Restaurant             Noodle House           Supermarket  ...
# 1   Moroccan Restaurant            Movie Theater                Museum  ...
# 2           Music Venue              Music Store          Music School  ...
# 3           Music Venue              Music Store                Museum  ...
# 4                   Pub  Comfort Food Restaurant            Restaurant  ...
#
#   11th Most Common Venue 12th Most Common Venue   13th Most Common Venue  \
# 0                 Office            Music Store              Music Venue
# 1            Music Store            Music Venue  New American Restaurant
# 2          Movie Theater           Noodle House      Monument / Landmark
# 3          Movie Theater    Moroccan Restaurant      Monument / Landmark
# 4       Sushi Restaurant           Liquor Store          Thai Restaurant
#
#             14th Most Common Venue      15th Most Common Venue  \
# 0          New American Restaurant               Movie Theater
# 1                        Nightclub                Noodle House
# 2  Molecular Gastronomy Restaurant  Modern European Restaurant
# 3  Molecular Gastronomy Restaurant  Modern European Restaurant
# 4                    Grocery Store            Toy / Game Store
#
#   16th Most Common Venue 17th Most Common Venue 18th Most Common Venue  \
# 0    Moroccan Restaurant              Nightclub    Monument / Landmark
# 1                 Office           Optical Shop     Mexican Restaurant
# 2     Miscellaneous Shop              Nightclub            Yoga Studio
# 3     Miscellaneous Shop                 Office            Yoga Studio
# 4           Cupcake Shop             Bagel Shop              Juice Bar
#
#             19th Most Common Venue 20th Most Common Venue
# 0  Molecular Gastronomy Restaurant           Music School
# 1                  Organic Grocery   Other Great Outdoors
# 2                           Office     Mexican Restaurant
# 3                      Opera House           Optical Shop
# 4                        Wine Shop    American Restaurant
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Cluster Neighborhoods

# %%
# set number of clusters
kclusters = 10

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 

# add clustering labels
#neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
neighborhoods_venues_sorted['Cluster Labels'] = kmeans.labels_
neighborhoods_venues_sorted['Cluster Labels'] = neighborhoods_venues_sorted['Cluster Labels'].astype(int)

toronto_merged = df

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_merged.head() # check the last columns!

# create map
map_clusters = folium.Map(location=lat_lng_coords, zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for index, row in toronto_merged.iterrows():
    if np.isnan(row['Cluster Labels']):
        continue
    lat = row['latitude']
    lng = row['longitude']
    poi = row['Neighborhood']
    cluster = int(row['Cluster Labels'])
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_dbba57c8fc0e41bcbc4b8541988d3a94%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_dbba57c8fc0e41bcbc4b8541988d3a94%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_dbba57c8fc0e41bcbc4b8541988d3a94%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_dbba57c8fc0e41bcbc4b8541988d3a94%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B43.651893615722656%2C-79.3817138671875%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20 ...

# %%
neighborhoods_venues_sorted.head()
# Out:
#                                       Neighborhood      1st Most Common Venue  \
# 0                                        Agincourt         Chinese Restaurant
# 1                           Alderwood, Long Branch             Breakfast Spot
# 2  Bathurst Manor, Wilson Heights, Downsview North  Middle Eastern Restaurant
# 3                                  Bayview Village                    Dog Run
# 4                Bedford Park, Lawrence Manor East                Coffee Shop
#
#       2nd Most Common Venue 3rd Most Common Venue       4th Most Common Venue  \
# 0                      Pool          Intersection                        Bank
# 1               Opera House    Miscellaneous Shop  Modern European Restaurant
# 2  Mediterranean Restaurant           Pizza Place                        Park
# 3              Tennis Court          Music School                Noodle House
# 4        Italian Restaurant        Sandwich Place               Women's Store
#
#              5th Most Common Venue    6th Most Common Venue  \
# 0                    Shopping Mall             Skating Rink
# 1  Molecular Gastronomy Restaurant      Monument / Landmark
# 2                           Museum  New American Restaurant
# 3                        Nightclub  New American Restaurant
# 4                           Bakery              Pizza Place
#
#   7th Most Common Venue    8th Most Common Venue 9th Most Common Venue  ...  \
# 0      Asian Restaurant             Noodle House           Supermarket  ...
# 1   Moroccan Restaurant            Movie Theater                Museum  ...
# 2           Music Venue              Music Store          Music School  ...
# 3           Music Venue              Music Store                Museum  ...
# 4                   Pub  Comfort Food Restaurant            Restaurant  ...
#
#   12th Most Common Venue   13th Most Common Venue  \
# 0            Music Store              Music Venue
# 1            Music Venue  New American Restaurant
# 2           Noodle House      Monument / Landmark
# 3    Moroccan Restaurant      Monument / Landmark
# 4           Liquor Store          Thai Restaurant
#
#             14th Most Common Venue      15th Most Common Venue  \
# 0          New American Restaurant               Movie Theater
# 1                        Nightclub                Noodle House
# 2  Molecular Gastronomy Restaurant  Modern European Restaurant
# 3  Molecular Gastronomy Restaurant  Modern European Restaurant
# 4                    Grocery Store            Toy / Game Store
#
#   16th Most Common Venue 17th Most Common Venue 18th Most Common Venue  \
# 0    Moroccan Restaurant              Nightclub    Monument / Landmark
# 1                 Office           Optical Shop     Mexican Restaurant
# 2     Miscellaneous Shop              Nightclub            Yoga Studio
# 3     Miscellaneous Shop                 Office            Yoga Studio
# 4           Cupcake Shop             Bagel Shop              Juice Bar
#
#             19th Most Common Venue 20th Most Common Venue Cluster Labels
# 0  Molecular Gastronomy Restaurant           Music School              1
# 1                  Organic Grocery   Other Great Outdoors              4
# 2                           Office     Mexican Restaurant              8
# 3                      Opera House           Optical Shop              1
# 4                        Wine Shop    American Restaurant              1
#
# [5 rows x 22 columns]

# %%
toronto_venues.head()
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0    Parkwoods              43.756123              -79.329636
# 1    Parkwoods              43.756123              -79.329636
# 2    Parkwoods              43.756123              -79.329636
# 3    Parkwoods              43.756123              -79.329636
# 4    Parkwoods              43.756123              -79.329636
#
#                Venue  Venue Latitude  Venue Longitude       Venue Category
# 0        649 Variety       43.754513       -79.331942    Convenience Store
# 1    TTC Stop #09083       43.759655       -79.332223             Bus Stop
# 2  DVP at York Mills       43.758899       -79.334099         Intersection
# 3        Chick-N-Joy       43.759900       -79.326520  Fried Chicken Joint
# 4      TTC Stop 9083       43.759251       -79.334000             Bus Stop

# %%
toronto_venues['Venue Category'].unique()
# Out:
# array(['Convenience Store', 'Bus Stop', 'Intersection',
#        'Fried Chicken Joint', 'Portuguese Restaurant', 'Coffee Shop',
#        'Pizza Place', 'Financial or Legal Service', 'Park', 'Bakery',
#        'Event Space', 'Italian Restaurant', 'Breakfast Spot',
#        'Thai Restaurant', 'German Restaurant', 'Café', 'Liquor Store',
#        'Theater', 'Spa', 'Bar', 'Discount Store', 'Yoga Studio',
#        'Sandwich Place', 'Skating Rink', 'Food Truck',
#        'Furniture / Home Store', 'Gym / Fitness Center', 'Platform',
#        'Metro Station', 'Video Game Store', 'Sushi Restaurant',
#        'Bubble Tea Shop', 'Mexican Restaurant', 'Dance Studio', 'Diner',
#        'Japanese Restaurant', 'Ramen Restaurant', 'Adult Boutique',
#        'Ethiopian Restaurant', 'Escape Room', 'Burrito Place',
#        'Distribution Center', 'Nightclub', 'Hobby Shop',
#        'College Theater', 'Gym', 'Beer Bar', 'Creperie',
#        'Martial Arts School', 'College Cafeteria', 'Bank', 'Pharmacy',
#        'Grocery Store', 'Shopping Mall', 'Fast Food Restaurant',
#        'Design Studio', 'Road', 'Pub', 'Comic Shop', 'Clothing Store',
#        'Music Venue', 'Middle Eastern Restaurant', 'Plaza', 'Hotel',
#        'Modern European Restaurant', 'Burger Joint', 'Steakhouse',
#        'Tea Room', 'Cosmetics Shop', 'Bookstore', 'Gastropub',
#        'College Rec Center', 'Historic Site', 'Chinese Restaurant',
#        'Vietnamese Restaurant', 'Restaurant', 'New American Restaurant',
#        'Seafood Restaurant', 'Miscellaneous Shop', 'Cocktail Bar',
#        'Falafel Restaurant', 'Poutine Place', 'Shoe Store',
#        'Movie Theater', 'Hookah Bar', 'Wine Bar', 'Dessert Shop',
#        'Department Store', 'Lingerie Store', 'Gas Station',
#        'Latin American Restaurant', 'Mediterranean Restaurant',
#        'Beer Store', 'Sporting Goods Shop', 'Dim Sum Restaurant',
#        'Art Gallery', 'Supermarket', 'Asian Restaurant', 'Bike Shop',
#        'Thrift / Vintage Store', 'Playground', 'Smoke Shop', 'Pet Store',
#        'American Restaurant', 'BBQ Joint',
#        'Vegetarian / Vegan Restaurant', 'Farmers Market', 'Jazz Club',
#        'Museum', 'Monument / Landmark', 'Comfort Food Restaurant',
#        'French Restaurant', 'Deli / Bodega', 'Lounge', 'Salad Place',
#        'Bistro', 'Moroccan Restaurant', 'Electronics Store',
#        'Performing Arts Venue', 'Irish Pub', 'Belgian Restaurant',
#        'Tailor Shop', 'Fountain', 'Salon / Barbershop', 'Field',
#        'Hockey Arena', 'Dog Run', 'Tennis Court', 'Trail',
#        'Soccer Stadium', 'Sports Bar', 'Greek Restaurant',
#        'Medical Center', 'Laundromat', 'Health Food Store',
#        'Neighborhood', 'Cheese Shop', 'Molecular Gastronomy Restaurant',
#        'Bagel Shop', 'Church', 'Indian Restaurant', 'Antique Shop',
#        'Concert Hall', 'Juice Bar', 'Hostel', 'Fish Market',
#        'Eastern European Restaurant', 'Gourmet Shop', 'Optical Shop',
#        'Poke Place', 'Business Service', 'Art Museum', 'Donut Shop',
#        'Korean Restaurant', 'Karaoke Bar', 'Ice Cream Shop',
#        'Candy Store', 'Baby Store', 'Gaming Cafe',
#        'Residential Building (Apartment / Condo)', 'Warehouse Store',
#        'Afghan Restaurant', 'Housing Development',
#        'Gluten-free Restaurant', 'Speakeasy', 'Opera House',
#        'Record Shop', 'Soup Place', 'Colombian Restaurant',
#        'Brazilian Restaurant', 'Food Court', 'Office', 'Cupcake Shop',
#        'Bus Line', 'Post Office', 'Athletics & Sports',
#        'Toy / Game Store', 'Supplement Shop', 'Jewelry Store',
#        'Chocolate Shop', 'Accessories Store', "Women's Store", 'Boutique',
#        'Caribbean Restaurant', 'Massage Studio', 'Automotive Shop',
#        'Lake', 'Basketball Stadium', 'IT Services', 'Boat or Ferry',
#        'Brewery', 'Cuban Restaurant', 'Malay Restaurant', 'Music Store',
#        "Men's Store", 'Gift Shop', 'Light Rail Station',
#        'Turkish Restaurant', 'Fruit & Vegetable Store',
#        'Tibetan Restaurant', 'Frozen Yogurt Shop', 'Train Station',
#        'General Travel', 'Arts & Crafts Store', 'Hawaiian Restaurant',
#        'Hotel Bar', 'Beach Bar', 'Stadium', 'Chiropractor', 'Bus Station',
#        'Pool', 'Indian Chinese Restaurant', 'Fish & Chips Shop',
#        'Board Shop', 'Snack Place', 'Basketball Court', 'Home Service',
#        'Baseball Field', 'Stationery Store', 'Taco Place', 'Climbing Gym',
#        'Gay Bar', 'Wine Shop', 'General Entertainment', 'College Stadium',
#        'Food & Drink Shop', 'Track', 'Cajun / Creole Restaurant',
#        'Flea Market', 'Wings Joint', 'Comedy Club', 'Gym Pool',
#        'Shoe Repair', 'Butcher', 'Flower Shop', 'Building',
#        'Noodle House', 'Indoor Play Area', 'Music School',
#        'College Arts Building', 'College Gym', 'Social Club',
#        'Smoothie Shop', 'School', 'Cantonese Restaurant',
#        'Organic Grocery', 'University', 'Peruvian Restaurant',
#        'Spanish Restaurant', 'Street Art', 'Video Store', 'Auto Garage',
#        'Other Great Outdoors', 'Camera Store', 'Pie Shop',
#        'Shop & Service', 'Taiwanese Restaurant', 'Rock Club', 'Market',
#        'Library', 'Theme Restaurant', 'Sake Bar', 'Strip Club',
#        'Sculpture Garden', 'Health & Beauty Service', 'Hardware Store',
#        'Tanning Salon'], dtype=object)
